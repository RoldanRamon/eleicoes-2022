# %%
Base de Dados Disponível em:

# %%
https://sig.tse.jus.br/ords/dwapr/seai/r/sig-eleicao-arquivo/confirma%C3%A7%C3%A3o-conjunto-de-dados?session=203500011924060
# Out:
#   File "/tmp/ipykernel_4768/3299489629.py", line 1
#     https://sig.tse.jus.br/ords/dwapr/seai/r/sig-eleicao-arquivo/confirma%C3%A7%C3%A3o-conjunto-de-dados?session=203500011924060
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv("detalhe_votacao.csv",encoding="cp1252",delimiter=";")

# %%
df.head()
# Out:
#    Ano de eleição                  Cargo  Código município  \
# 0            2022  Conselheiro Distrital             30015
# 1            2022     Deputado Distrital             97012
# 2            2022     Deputado Distrital             97012
# 3            2022     Deputado Distrital             97012
# 4            2022     Deputado Distrital             97012
#
#              Município        Região  Turno  UF  Zona  \
# 0  FERNANDO DE NORONHA      NORDESTE      1  PE     4
# 1             BRASÍLIA  CENTRO-OESTE      1  DF     1
# 2             BRASÍLIA  CENTRO-OESTE      1  DF     2
# 3             BRASÍLIA  CENTRO-OESTE      1  DF     3
# 4             BRASÍLIA  CENTRO-OESTE      1  DF     4
#
#    Quantidade de votos brancos  Quantidade de votos de legenda válidos  ...  \
# 0                           26                                       0  ...
# 1                         2441                                    2753  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39967 entries, 0 to 39966
# Data columns (total 35 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Ano de eleição                                      39967 non-null  int64
#  1   Cargo                                               39967 non-null  object
#  2   Código município                                    39967 non-null  int64
#  3   Município                                           39967 non-null  object
#  4   Região                                              39967 non-null  object
#  5   Turno                                               39967 non-null  int64
#  6   UF                                                  39967 non-null  object
#  7   Zona                                                39967 non-null  int64
# ...
